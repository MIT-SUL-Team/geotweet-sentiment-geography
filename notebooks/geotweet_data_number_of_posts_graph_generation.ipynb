# %% [markdown]
# # Geotweet Data Number of Posts Graph Generation

# %% [markdown]
# Author: @SirenaYu
#
# This notebook include scripts to generate daily number of posts (geotagged, sentiment, common) graphs from 2012 to 2021.

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
from datetime import date, timedelta
from script import leap_year
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
def get_date_list(year):
    base = date(year, 1, 1)
    numdays = 365 + int(leap_year(year))*1
    return [base + timedelta(days=x) for x in range(numdays)]

# %% [markdown]
# # 2012 Summary

# %%
summary_df_2012 = pd.read_csv('master_2012_summary.csv')

x = get_date_list(2012)
y_geo = summary_df_2012['num_geo_posts']
y_sent = summary_df_2012['num_sent_posts']
y_common = summary_df_2012['num_common_posts']

plt.plot(x, y_geo, color='silver', label="Geotagged Posts")
plt.plot(x, y_sent, color='grey', label="Posts with Sentiment Scores")
plt.plot(x, y_common, color='green', label="Common Posts")

plt.title("Number of Posts by Day in 2012")
plt.legend(bbox_to_anchor=(1.6, 1.0), loc='upper right')

plt.show()

# %%
avg_common_out_of_geo = (summary_df_2012['num_common_posts']/summary_df_2012['num_geo_posts']).mean(skipna=True)
avg_common_out_of_sent = (summary_df_2012['num_common_posts']/summary_df_2012['num_sent_posts']).mean(skipna=True)

pd.DataFrame(data = [[avg_common_out_of_geo, avg_common_out_of_sent]],
            columns=["common/geo", "common/sent"],
            index = [2012])
# Out:
#       common/geo  common/sent
# 2012    0.996208     0.944947

# %% [markdown]
# # 2013 Summary

# %%
summary_df_2013 = pd.read_csv('master_2013_summary.csv')

x = get_date_list(2013)
y_geo = summary_df_2013['num_geo_posts']
y_sent = summary_df_2013['num_sent_posts']
y_common = summary_df_2013['num_common_posts']

plt.plot(x, y_geo, color='silver', label="Geotagged Posts")
plt.plot(x, y_sent, color='grey', label="Posts with Sentiment Scores")
plt.plot(x, y_common, color='green', label="Common Posts")

plt.title("Number of Posts by Day in 2013")
plt.legend(bbox_to_anchor=(1.6, 1.0), loc='upper right')

plt.show()

# %%
avg_common_out_of_geo = (summary_df_2013['num_common_posts']/summary_df_2013['num_geo_posts']).mean(skipna=True)
avg_common_out_of_sent = (summary_df_2013['num_common_posts']/summary_df_2013['num_sent_posts']).mean(skipna=True)

pd.DataFrame(data = [[avg_common_out_of_geo, avg_common_out_of_sent]],
            columns=["common/geo", "common/sent"],
            index = [2013])
# Out:
#       common/geo  common/sent
# 2013    0.990341     0.921282

# %% [markdown]
# # 2014 Summary

# %%
summary_df_2014 = pd.read_csv('master_2014_summary.csv')

x = get_date_list(2014)
y_geo = summary_df_2014['num_geo_posts']
y_sent = summary_df_2014['num_sent_posts']
y_common = summary_df_2014['num_common_posts']

plt.plot(x, y_geo, color='silver', label="Geotagged Posts")
plt.plot(x, y_sent, color='grey', label="Posts with Sentiment Scores")
plt.plot(x, y_common, color='green', label="Common Posts")

plt.title("Number of Posts by Day in 2014")
plt.legend(bbox_to_anchor=(1.6, 1.0), loc='upper right')

plt.show()

# %% [markdown]
# # 2015 Summary

# %%
summary_df_2015 = pd.read_csv('master_2015_summary.csv')

x = get_date_list(2015)
y_geo = summary_df_2015['num_geo_posts']
y_sent = summary_df_2015['num_sent_posts']
y_common = summary_df_2015['num_common_posts']

plt.plot(x, y_geo, color='silver', label="Geotagged Posts")
plt.plot(x, y_sent, color='grey', label="Posts with Sentiment Scores")
plt.plot(x, y_common, color='green', label="Common Posts")

plt.title("Number of Posts by Day in 2015")
plt.legend(bbox_to_anchor=(1.6, 1.0), loc='upper right')

plt.show()

# %%
avg_common_out_of_geo = (summary_df_2015['num_common_posts']/summary_df_2015['num_geo_posts']).mean(skipna=True)
avg_common_out_of_sent = (summary_df_2015['num_common_posts']/summary_df_2015['num_sent_posts']).mean(skipna=True)

pd.DataFrame(data = [[avg_common_out_of_geo, avg_common_out_of_sent]],
            columns=["common/geo", "common/sent"],
            index = [2015])
# Out:
#       common/geo  common/sent
# 2015    0.999999     0.963056

# %% [markdown]
# # 2016 Summary

# %%
summary_df_2016 = pd.read_csv('../output/master_2016_summary.csv')

x = get_date_list(2016)
y_geo = summary_df_2016['num_geo_posts']
y_sent = summary_df_2016['num_sent_posts']
y_common = summary_df_2016['num_common_posts']

plt.plot(x, y_geo, color='silver', label="Geotagged Posts")
plt.plot(x, y_sent, color='grey', label="Posts with Sentiment Scores")
plt.plot(x, y_common, color='green', label="Common Posts")

plt.title("Number of Posts by Day in 2016")
plt.legend(bbox_to_anchor=(1.6, 1.0), loc='upper right')

plt.show()

# %% [markdown]
# # 2017 Summary

# %%
summary_df_2017 = pd.read_csv('../output/master_2017_summary.csv')

x = get_date_list(2017)
y_geo = summary_df_2017['num_geo_posts']
y_sent = summary_df_2017['num_sent_posts']
y_common = summary_df_2017['num_common_posts']

plt.plot(x, y_geo, color='silver', label="Geotagged Posts")
plt.plot(x, y_sent, color='grey', label="Posts with Sentiment Scores")
plt.plot(x, y_common, color='green', label="Common Posts")

plt.title("Number of Posts by Day in 2017")
plt.legend(bbox_to_anchor=(1.6, 1.0), loc='upper right')

plt.show()

# %% [markdown]
# # 2018 Summary

# %%
summary_df_2018 = pd.read_csv('../output/master_2018_summary.csv')

x = get_date_list(2018)
y_geo = summary_df_2018['num_geo_posts']
y_sent = summary_df_2018['num_sent_posts']
y_common = summary_df_2018['num_common_posts']

plt.plot(x, y_geo, color='silver', label="Geotagged Posts")
plt.plot(x, y_sent, color='grey', label="Posts with Sentiment Scores")
plt.plot(x, y_common, color='green', label="Common Posts")

plt.title("Number of Posts by Day in 2018")
plt.legend(bbox_to_anchor=(1.6, 1.0), loc='upper right')

plt.show()

# %% [markdown]
# # 2019 Summary

# %%
summary_df_2019 = pd.read_csv('../output/master_2019_summary.csv')

x = get_date_list(2019)
y_geo = summary_df_2019['num_geo_posts']
y_sent = summary_df_2019['num_sent_posts']
y_common = summary_df_2019['num_common_posts']

plt.plot(x, y_geo, color='silver', label="Geotagged Posts")
plt.plot(x, y_sent, color='grey', label="Posts with Sentiment Scores")
plt.plot(x, y_common, color='green', label="Common Posts")

plt.title("Number of Posts by Day in 2019")
plt.legend(bbox_to_anchor=(1.6, 1.0), loc='upper right')

plt.show()

# %% [markdown]
# # 2020 Summary

# %%
summary_df_2020 = pd.read_csv('../output/master_2020_summary.csv')

x = get_date_list(2020)
y_geo = summary_df_2020['num_geo_posts']
y_sent = summary_df_2020['num_sent_posts']
y_common = summary_df_2020['num_common_posts']

plt.plot(x, y_geo, color='silver', label="Geotagged Posts")
plt.plot(x, y_sent, color='grey', label="Posts with Sentiment Scores")
plt.plot(x, y_common, color='green', label="Common Posts")

plt.title("Number of Posts by Day in 2020")
plt.legend(bbox_to_anchor=(1.6, 1.0), loc='upper right')

plt.show()

# %% [markdown]
# # 2021 Summary

# %%
summary_df_2021 = pd.read_csv('../output/master_2021_summary.csv')

x = get_date_list(2021)
y_geo = summary_df_2021['num_geo_posts']
y_sent = summary_df_2021['num_sent_posts']
y_common = summary_df_2021['num_common_posts']

plt.plot(x, y_geo, color='silver', label="Geotagged Posts")
plt.plot(x, y_sent, color='grey', label="Posts with Sentiment Scores")
plt.plot(x, y_common, color='green', label="Common Posts")

plt.title("Number of Posts by Day in 2021")
plt.legend(bbox_to_anchor=(1.6, 1.0), loc='upper right')

plt.show()
